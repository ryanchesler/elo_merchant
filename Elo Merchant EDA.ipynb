# %%
import pandas as pd
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train["first_active_month"].min()
# Out:
# '2011-11'

# %%
train["first_active_month"].max()
# Out:
# '2018-02'

# %%
train["first_active_month"].value_counts().plot()

# %%
test["first_active_month"].value_counts().plot()

# %%
print(test.shape)
print(train.shape)
# Out:
# (123623, 5)
# (201917, 6)

# %%
new_merchant_transactions = pd.read_csv("new_merchant_transactions.csv")

# %%
new_merchant_transactions.drop("authorized_flag", axis = 1, inplace = True)

# %%
categorical = ["city_id", "category_1", "category_3", "merchant_category_id", "category_2", "state_id", "subsector_id"]
for column in categorical:
    print(column)
    print(new_merchant_transactions[column].value_counts())
# Out:
# city_id
#  69     328916
# -1       99349
#  158     84962
#  19      70961
#  17      65300
#  143     53997
#  88      46301
#  137     45007
#  331     41429
#  87      33967
#  212     32143
#  333     31354
#  25      28315
#  233     26682
#  57      23514
#  160     23132
#  149     22288
#  291     22112
#  213     21042
#  117     20500
#  140     17831
#  4       16672
#  277     16624
#  286     16030
#  107     15629
#  76      14424
#  53      14319
#  161     13679
#  231     13140
#  20      13117
#          ...
#  336       548
#  237       540
#  18        530
#  235       520
#  26        517
#  71        512
#  293       510
#  84        501
#  254       465
#  112       460
#  221       451
#  130       444
#  32        439
#  222       425
#  205       375
#  227       357
#  122       297
#  204       291
#  89        276
#  315       262
#  306       262
#  178       245
#  263       242
#  207       152
#  215       145
#  319        57
#  92         25
# ...

# %%
merged_train_df = pd.merge(train, new_merchant_transactions, on ="card_id", how = "left")
merged_test_df = pd.merge(test, new_merchant_transactions, on ="card_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-7fec88a088ea> in <module>()
# ----> 1 merged_train_df = pd.merge(train, new_merchant_transactions, on ="card_id", how = "left_only")
#       2 merged_test_df = pd.merge(test, new_merchant_transactions, on ="card_id")
#
# c:\users\magic\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# c:\users\magic\appdata\local\programs\python\python36\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     566                 self.left, self.right)
#     567
# ...

# %%
merged_train_df.shape
# Out:
# (1219685, 18)

# %%
aggregators = {"card_id": ["sum", "mean", "max", "min", "count", "std"]}
new_merchant_transactions.groupby(aggregators)

# %%
new_merchant_transactions
# Out:
#                  card_id  city_id category_1  installments category_3  \
# 0        C_ID_415bb3a509      107          N             1          B
# 1        C_ID_415bb3a509      140          N             1          B
# 2        C_ID_415bb3a509      330          N             1          B
# 3        C_ID_415bb3a509       -1          Y             1          B
# 4        C_ID_ef55cf8d4b       -1          Y             1          B
# 5        C_ID_ef55cf8d4b      231          N             1          B
# 6        C_ID_ef55cf8d4b       69          N             1          B
# 7        C_ID_ef55cf8d4b      231          N             1          B
# 8        C_ID_ef55cf8d4b       69          N             1          B
# 9        C_ID_ef55cf8d4b       69          N             1          B
# 10       C_ID_ef55cf8d4b       69          N            -1        NaN
# 11       C_ID_ef55cf8d4b       69          N             1          B
# ...
